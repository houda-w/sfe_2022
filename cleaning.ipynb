# %%
import pandas as pd

# %%
df = pd.read_excel('BD SELECTION O TEIMA_01-11-2021.xlsx', header=[1])
df
# Out:
#         Code UP  ZONE         Nom UP   N° SNIT génisse N° SNIT génisse_1  \
# 0      M-09-014  MASSA  BOUZOUAI ALI  MAR06BB000096118               NaN
# 1      M-09-014  MASSA  BOUZOUAI ALI  MAR06BE000096119               NaN
# 2      M-09-014  MASSA  BOUZOUAI ALI  MAR06BI000096120               NaN
# 3      M-09-014  MASSA  BOUZOUAI ALI  MAR06BB000096121               NaN
# 4      M-09-014  MASSA  BOUZOUAI ALI  MAR06BE000096122               NaN
# ...         ...    ...           ...               ...               ...
# 13617       NaN    NaN           NaN  MAR06BE000394406               NaN
# 13618       NaN    NaN           NaN  MAR06BB000394405               NaN
# 13619       NaN    NaN           NaN  MAR06BB000446438               NaN
# 13620       NaN    NaN           NaN  MAR06BJ000394399               NaN
# 13621       NaN    NaN           NaN  MAR06BI000394404               NaN
#
#       N° SNIT génisse_2 N° CARTE SNIT    Date de naissance RACE  \
# ...

# %%
df.isna().sum()
# Out:
# Code UP                              1127
# ZONE                                  508
# Nom UP                                 15
# N° SNIT génisse                         2
# N° SNIT génisse_1                   12996
# N° SNIT génisse_2                   13621
# N° CARTE SNIT                       10699
# Date de naissance                      17
# RACE                                  154
# N° SNIT Mère                         1213
# N° SNIT Mère_1                      13170
# N° SNIT Mère_2                      13611
# N° SNIT père ou nom (taureau IA)     1248
# Date de sélection                      15
# OBSERVATION                            17
# Unnamed: 15                         13622
# Unnamed: 16                         13618
# dtype: int64

# %%
df.columns
# Out:
# Index(['Code UP', 'ZONE ', 'Nom UP', 'N° SNIT génisse', 'N° SNIT génisse_1',
#        'N° SNIT génisse_2', 'N° CARTE SNIT', 'Date de naissance', 'RACE',
#        'N° SNIT Mère', 'N° SNIT Mère_1', 'N° SNIT Mère_2',
#        'N° SNIT père ou nom (taureau IA)', 'Date de sélection', 'OBSERVATION',
#        'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Code UP                                     object
# ZONE                                        object
# Nom UP                                      object
# N° SNIT génisse                             object
# N° SNIT génisse_1                           object
# N° SNIT génisse_2                           object
# N° CARTE SNIT                               object
# Date de naissance                           object
# RACE                                        object
# N° SNIT Mère                                object
# N° SNIT Mère_1                              object
# N° SNIT Mère_2                              object
# N° SNIT père ou nom (taureau IA)            object
# Date de sélection                   datetime64[ns]
# OBSERVATION                                 object
# Unnamed: 15                                float64
# Unnamed: 16                                 object
# dtype: object

# %%
k= df[df['Unnamed: 16'].notna()]
k
# Out:
#        Code UP    ZONE          Nom UP   N° SNIT génisse N° SNIT génisse_1  \
# 2831  O-09-026  O TEIMA  LAGRIDANI ALI  MAR06BE000194707               NaN
# 2832  O-09-026  O TEIMA  LAGRIDANI ALI  MAR06BD000187432               NaN
# 2833  O-09-026  O TEIMA  LAGRIDANI ALI  MAR06BF000231704               NaN
# 2834  O-09-026  O TEIMA  LAGRIDANI ALI  MAR06BB000231706               NaN
#
#      N° SNIT génisse_2 N° CARTE SNIT    Date de naissance RACE  \
# 2831               NaN           NaN  2016-07-28 00:00:00  HOL
# 2832               NaN           NaN  2016-08-03 00:00:00  HOL
# 2833               NaN           NaN  2016-08-10 00:00:00  HOL
# 2834               NaN           NaN  2016-08-13 00:00:00  HOL
#
#           N° SNIT Mère N° SNIT Mère_1 N° SNIT Mère_2  \
# 2831  MAR06BI000152068            NaN            NaN
# 2832  MAR06BB000152001            NaN            NaN
# 2833  MAR06BF000152067            NaN            NaN
# 2834  MAR06BE000152086            NaN            NaN
#
# ...

# %%
df_subset  = df[['Code UP', 'ZONE ', 'Nom UP', 'N° SNIT génisse', 'N° SNIT génisse_1',
       'N° SNIT génisse_2', 'N° CARTE SNIT', 'Date de naissance', 'RACE',
       'N° SNIT Mère', 'N° SNIT Mère_1', 'N° SNIT Mère_2',
       'N° SNIT père ou nom (taureau IA)', 'Date de sélection', 'OBSERVATION']]
df_subset
# Out:
#         Code UP  ZONE         Nom UP   N° SNIT génisse N° SNIT génisse_1  \
# 0      M-09-014  MASSA  BOUZOUAI ALI  MAR06BB000096118               NaN
# 1      M-09-014  MASSA  BOUZOUAI ALI  MAR06BE000096119               NaN
# 2      M-09-014  MASSA  BOUZOUAI ALI  MAR06BI000096120               NaN
# 3      M-09-014  MASSA  BOUZOUAI ALI  MAR06BB000096121               NaN
# 4      M-09-014  MASSA  BOUZOUAI ALI  MAR06BE000096122               NaN
# ...         ...    ...           ...               ...               ...
# 13617       NaN    NaN           NaN  MAR06BE000394406               NaN
# 13618       NaN    NaN           NaN  MAR06BB000394405               NaN
# 13619       NaN    NaN           NaN  MAR06BB000446438               NaN
# 13620       NaN    NaN           NaN  MAR06BJ000394399               NaN
# 13621       NaN    NaN           NaN  MAR06BI000394404               NaN
#
#       N° SNIT génisse_2 N° CARTE SNIT    Date de naissance RACE  \
# ...

# %%
uniqueRace = df_subset['OBSERVATION'].unique()
uniqueRace
# Out:
# array(['OK', 'NON TROUVEE', 'NON PRESENTEE', 'CNC',
#        'NON BOUCLEE LE "16-02-2017"', 'DECES', 'MERE NON CONFORME',
#        'SORTIE', 'MNC (GENEALOGIE)', 'PÈRE NON CONFORME',
#        'CONFORMATION NON CONFORME', 'MERE NON CONFORME (GENEALOGIE)',
#        'RACE A VINADE', 'CROISEE (HOL*BBB)',
#        'NON BOUCLEE "LE 23-02-2017" ',
#        'AGE NON CONFORME + MERE NON CONFORME (LAIT)',
#        'CONFOMRATION NON CONFORME', 'MERE NON CONFORME (LAIT)', 'CROISEE',
#        'AGE NON CONFORME + MERE NON CONFORME (GENEALOGIE)',
#        'MERE NON CONFORME (LAIT) + MERE NON CONFORME (GENEALOGIE)',
#        'MALE', 'DÉJÀ SELECTIONNEE LE 18/05/2016',
#        'NON PRESENTEE LE 09-03-2017', 'NON PRESENTEE LE 09-03-2018',
#        'GENISSE NON PRODUITE SUR UNITE',
#        'MERE NON CONFORME (GENEALOGIE) + NAISSANCE NON SIGNALE AU NIVEAU DE REGISTRE DES NAISSANCES',
#        'NON PRESENTEE LE "16/03/2017"', 'RACE A VIANDE', 'CROISEE HL*MB',
# ...

# %%
df_subset.drop(df_subset.tail(3).index,inplace=True)
df_subset
# Out:
# C:\Users\Houda S\AppData\Local\Temp\ipykernel_10604\3419433938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.drop(df_subset.tail(3).index,inplace=True)
#         Code UP        ZONE                     Nom UP   N° SNIT génisse  \
# 0      M-09-014        MASSA              BOUZOUAI ALI  MAR06BB000096118
# 1      M-09-014        MASSA              BOUZOUAI ALI  MAR06BE000096119
# 2      M-09-014        MASSA              BOUZOUAI ALI  MAR06BI000096120
# 3      M-09-014        MASSA              BOUZOUAI ALI  MAR06BB000096121
# 4      M-09-014        MASSA              BOUZOUAI ALI  MAR06BE000096122
# ...         ...          ...                       ...               ...
# 13602  M-15-172        MASSA  WAGAGUE IDRISSI MOHAMMED  MAR06BC000359159
# ...

# %%
df_subset['OBSERVATION'] = df_subset['OBSERVATION'].replace(['age non conforme'],'AGE NON CONFORME')
# Out:
# C:\Users\Houda S\AppData\Local\Temp\ipykernel_4756\1948547429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['OBSERVATION'] = df_subset['OBSERVATION'].replace(['age non conforme'],'AGE NON CONFORME')

# %%
df_subset.loc[df_subset.OBSERVATION=='Mére Non Conforme','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C.','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE N.C (Généalogie)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE N.C (GENEALOGIE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME GENEALOGIE','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (CROISEMENT MB*FLECKVIEH)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION==' MERE NON CONFORME (GENEALOGIE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME GENEALOGIE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME(ORIGINE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFOMRE','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C (TF)','OBSERVATION']= 'MNC'

# %%
df_subset.loc[df_subset.OBSERVATION=='MNC (TF)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C (TF)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE N.C (LAIT)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C (TF)','OBSERVATION']= 'MNC'

# %%
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (GENEALOGIE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MNC (GENEALOGIE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (ORIGINE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE MON CONFORME (F.L.)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONORME (GENEALOGIE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='mere non conforme','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (FLK*MB)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (F.L.)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MNC (ORIGINE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C (INCONNU)','OBSERVATION']= 'MNC'

# %%
df_subset.loc[df_subset.OBSERVATION=='CONFORMATION NON CONFORME','OBSERVATION']= 'CNC'
df_subset.loc[df_subset.OBSERVATION=='CONFOMRATION NON CONFORME','OBSERVATION']= 'CNC'
df_subset.loc[df_subset.OBSERVATION=='C.N.C.','OBSERVATION']= 'CNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (PURETE RACE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='C.N.C','OBSERVATION']= 'CNC'

df_subset.loc[df_subset.OBSERVATION=='NON PRESENTEE LE 09-03-2017','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESENTEE LE 09-03-2018','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESENTEE LE "16/03/2017"','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESENTEE LE "23-03-2017"','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESENTEE LE 21-06-2017','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESENTEE LE 30/11/2017','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESENTEE ','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NP','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='non presentee','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='non présentée','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='non présentée ','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESNTEE','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESENTEE ','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESENTEE 30-01-2018','OBSERVATION']= 'NON PRESENTEE'

# %%
uniqueRace = df_subset['OBSERVATION'].unique()
uniqueRace
# Out:
# array(['OK', 'NON TROUVEE', 'NON PRESENTEE', 'CNC',
#        'NON BOUCLEE LE "16-02-2017"', 'DECES', 'MNC', 'SORTIE',
#        'PÈRE NON CONFORME', 'RACE A VINADE', 'CROISEE (HOL*BBB)',
#        'NON BOUCLEE "LE 23-02-2017" ',
#        'AGE NON CONFORME + MERE NON CONFORME (LAIT)', 'CROISEE',
#        'AGE NON CONFORME + MERE NON CONFORME (GENEALOGIE)',
#        'MERE NON CONFORME (LAIT) + MERE NON CONFORME (GENEALOGIE)',
#        'MALE', 'DÉJÀ SELECTIONNEE LE 18/05/2016',
#        'GENISSE NON PRODUITE SUR UNITE',
#        'MERE NON CONFORME (GENEALOGIE) + NAISSANCE NON SIGNALE AU NIVEAU DE REGISTRE DES NAISSANCES',
#        'RACE A VIANDE', 'CROISEE HL*MB',
#        'MERE NON CONFORME (LAIT) + AGE NON CONFORME',
#        'NON BOUCLE LE "17/04/2017"',
#        'NON PRESENTEE LE 21-06-2017 ET MERE NON CONFORME (PEDIGREE)',
#        'MERE NON CONFORME (PROBLEME CARTE SNIT) + CONFORMATION NON CONFORME',
#        'ANC', 'AGE NON CONFORME + MERE NON CONFORME (PEDIGRE)',
# ...

# %%
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (LAIT)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (PEDIGREE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (PEDIGREE + PROBLEME CARTE SNIT))','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (PROBLEME CARTE SNIT)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (PEDIGRE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='Mére non conforme','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (MANQUE INFORMATIONS)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (TAUREAU FERME)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (TAUREAU DE FERME)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (CROISEE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (LAIT: DISCORDANCE DES VALEURS ENTRE FICHE LACTATION ET RAPPORT MENSUEL DU CONTROLE LAITIER)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME GENEALOGIE: CROISEMENT)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (GENELOGIE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON ONFORME (MANQUE INFORMATIONS)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (Généalogie)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C (LACTATION)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C (LAIT) ','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C (LAIT)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MNC (LAIT)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C (GENEALOGIE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MNC (GMM 2 VELAGES EN 3 SEMAINES)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MNC (ISSUE TF)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MNC (LAIT VELAGE NON DECLARE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MNC (RACE INCONNUE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE N.C (Vêlage N.déclarée)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MNC (CROISEE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='M.N.C (PURETE)','OBSERVATION']= 'MNC'
df_subset.loc[df_subset.OBSERVATION=='MERE NON CONFORME (PURETE)','OBSERVATION']= 'MNC'

# %%
df_subset.loc[df_subset.OBSERVATION=='Non trouvée','OBSERVATION']= 'NON TROUVEE'
df_subset.loc[df_subset.OBSERVATION=='non trouvée','OBSERVATION']= 'NON TROUVEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESNETEE','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='NON PRESENTER','OBSERVATION']= 'NON PRESENTEE'
df_subset.loc[df_subset.OBSERVATION=='AGE NON CONFORME','OBSERVATION']= 'ANC'
df_subset.loc[df_subset.OBSERVATION=='age non conforme','OBSERVATION']= 'ANC'
df_subset.loc[df_subset.OBSERVATION=='ok','OBSERVATION']= 'OK'

# %%
df_subset.to_excel('cleaned_BDSelect.xlsx',index=False)

# %%
cleaned_df =pd.read_excel('cleaned_BDSelect.xlsx')
cleaned_df
# Out:
#         Code UP       ZONE                     Nom UP   N° SNIT génisse  \
# 0      M-09-014       MASSA              BOUZOUAI ALI  MAR06BB000096118
# 1      M-09-014       MASSA              BOUZOUAI ALI  MAR06BE000096119
# 2      M-09-014       MASSA              BOUZOUAI ALI  MAR06BI000096120
# 3      M-09-014       MASSA              BOUZOUAI ALI  MAR06BB000096121
# 4      M-09-014       MASSA              BOUZOUAI ALI  MAR06BE000096122
# ...         ...         ...                       ...               ...
# 13658  T-07-059   TAROUDANT  EL BOUDERKAOUI MY Brahim  MAR06BE000214120
# 13659  T-07-059   TAROUDANT  EL BOUDERKAOUI MY Brahim  MAR06BA000214122
# 13660  T-15-157   TAROUDANT            SALAMOU MBAREK  MAR06BH000267112
# 13661  B-07-046    O BERHIL             EZZYADI Fatah  MAR06BI000330891
# 13662  G-15-177  ELGUERDANE         EL MOUDEN ELHABIB  MAR06BH000300529
#
#       N° SNIT génisse_1 N° SNIT génisse_2 N° CARTE SNIT    Date de naissance  \
# ...

# %%
uniqueRace = cleaned_df['RACE'].unique()
uniqueRace
# Out:
# array(['HOL', 'MB', 'Brune Suisse', 'BRUNE SUISSE', 'BR SUISSE', 'RH',
#        'BR,SS', 'BRAL', 'CROISEE', 'B S', 'FLK', 'BRA', 'BA', 'FLECK',
#        'HOLSTEIN', nan, 'F', 'BR AL', 'HL', 'FLECKVIEH'], dtype=object)

# %%
cleaned_df.loc[cleaned_df.RACE=='HOL','RACE']= 'HOLSTEIN'
cleaned_df.loc[cleaned_df.RACE=='HL','RACE']= 'HOLSTEIN'
cleaned_df.loc[cleaned_df.RACE=='Brune Suisse','RACE']= 'BRUNE SUISSE'
cleaned_df.loc[cleaned_df.RACE=='BR SUISSE','RACE']= 'BRUNE SUISSE'
cleaned_df.loc[cleaned_df.RACE=='BR,SS','RACE']= 'BRUNE SUISSE'
cleaned_df.loc[cleaned_df.RACE=='B S','RACE']= 'BRUNE SUISSE'
cleaned_df.loc[cleaned_df.RACE=='FLK','RACE']= 'FLECKVIEH'
cleaned_df.loc[cleaned_df.RACE=='FLECK','RACE']= 'FLECKVIEH'
cleaned_df.loc[cleaned_df.RACE=='F','RACE']= 'FLECKVIEH'

# %%
cleaned_df.loc[cleaned_df.RACE=='BRA','RACE']= 'BRUNE AL'
cleaned_df.loc[cleaned_df.RACE=='BA','RACE']= 'BRUNE AL'
cleaned_df.loc[cleaned_df.RACE=='BRAL','RACE']= 'BRUNE AL'

# %%
cleaned_df
# Out:
#         Code UP       ZONE                     Nom UP   N° SNIT génisse  \
# 0      M-09-014       MASSA              BOUZOUAI ALI  MAR06BB000096118
# 1      M-09-014       MASSA              BOUZOUAI ALI  MAR06BE000096119
# 2      M-09-014       MASSA              BOUZOUAI ALI  MAR06BI000096120
# 3      M-09-014       MASSA              BOUZOUAI ALI  MAR06BB000096121
# 4      M-09-014       MASSA              BOUZOUAI ALI  MAR06BE000096122
# ...         ...         ...                       ...               ...
# 13658  T-07-059   TAROUDANT  EL BOUDERKAOUI MY Brahim  MAR06BE000214120
# 13659  T-07-059   TAROUDANT  EL BOUDERKAOUI MY Brahim  MAR06BA000214122
# 13660  T-15-157   TAROUDANT            SALAMOU MBAREK  MAR06BH000267112
# 13661  B-07-046    O BERHIL             EZZYADI Fatah  MAR06BI000330891
# 13662  G-15-177  ELGUERDANE         EL MOUDEN ELHABIB  MAR06BH000300529
#
#       N° SNIT génisse_1 N° SNIT génisse_2 N° CARTE SNIT    Date de naissance  \
# ...

# %%
uniqueUP = cleaned_df['Nom UP'].unique()
uniqueUP
# Out:
# array(['BOUZOUAI ALI', 'DKAIR AHMED', 'LACHGAR SAID', 'CHOUKRI HASSAN',
#        'AIT CHAGUER MOHAMED', 'OUHNA BRAHIM', 'BELKADI NASSER',
#        'SEBAAY EL MOSTAFA', 'EL HAROUCH MOHAMED', 'IBNOU RASS ABDELKARIM',
#        'CHOUFANI ABDELMALEK', 'AMGOUNE MAHJOUB', 'EL ADOUDI TAYEB',
#        'BOUTERHA AOMAR', 'ALA ABDERRAHMANE', 'BELHASSAN ABDELLATIF',
#        'ABID ABDELLATIF', 'LAZIM MOHAMED', 'ALLAOUI MOHAMED',
#        'SIDKQI OTHMAN', 'OUMELLOUK BOUJEMAA', 'RAFI MOHAMED AMINE',
#        'BOUKDIR OMAR', 'KABEL MOHAMED', 'KAYOUH ABDENAIM',
#        'ABRASSOU ABDELLAH', 'MAKTANE SAID', 'LOULTITI MY RACHID',
#        'ABDAIMI AHMED', 'BELHASSAN EL HASSAN', 'ES-SALEHY IDRISS',
#        'ALIOUA ABDALLAH', 'MOSTAGHFIR MOHAMED', 'AIT SALEM MOHAMED',
#        'ACHANDIR HICHAM', 'ALHIANE BOURHIM', 'EL AABOUBI KHALID',
#        "LKAM M'HAMED", 'BISSA ISMAIL', "LOULTITI MY M'HAMED",
#        'TAOUFIQ ABDERRAHMANE', 'AIT KARROUM LARBI', 'MOUHALA AMAL',
# ...

# %%
cleaned_df.to_excel('final_BDSelect.xlsx',index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.figure import Figure
